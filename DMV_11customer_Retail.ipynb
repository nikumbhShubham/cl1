# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df= pd.read_csv("customer_shopping_data.csv")
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.groupby("shopping_mall").count()
# Out:
#                    invoice_no  customer_id  gender    age  category  quantity  \
# shopping_mall
# Cevahir AVM              4991         4991    4991   4991      4991      4991
# Emaar Square Mall        4811         4811    4811   4811      4811      4811
# Forum Istanbul           4947         4947    4947   4947      4947      4947
# Istinye Park             9781         9781    9781   9781      9781      9781
# Kanyon                  19823        19823   19823  19823     19823     19823
# Mall of Istanbul        19943        19943   19943  19943     19943     19943
# Metrocity               15011        15011   15011  15011     15011     15011
# Metropol AVM            10161        10161   10161  10161     10161     10161
# Viaport Outlet           4914         4914    4914   4914      4914      4914
# Zorlu Center             5075         5075    5075   5075      5075      5075
#
#                    price  payment_method  invoice_date
# shopping_mall
# Cevahir AVM         4991            4991          4991
# Emaar Square Mall   4811            4811          4811
# Forum Istanbul      4947            4947          4947
# Istinye Park        9781            9781          9781
# Kanyon             19823           19823         19823
# Mall of Istanbul   19943           19943         19943
# Metrocity          15011           15011         15011
# Metropol AVM       10161           10161         10161
# Viaport Outlet      4914            4914          4914
# Zorlu Center        5075            5075          5075

# %%
df.groupby("category").count()
# Out:
#                  invoice_no  customer_id  gender    age  quantity  price  \
# category
# Books                  4981         4981    4981   4981      4981   4981
# Clothing              34487        34487   34487  34487     34487  34487
# Cosmetics             15097        15097   15097  15097     15097  15097
# Food & Beverage       14776        14776   14776  14776     14776  14776
# Shoes                 10034        10034   10034  10034     10034  10034
# Souvenir               4999         4999    4999   4999      4999   4999
# Technology             4996         4996    4996   4996      4996   4996
# Toys                  10087        10087   10087  10087     10087  10087
#
#                  payment_method  invoice_date  shopping_mall
# category
# Books                      4981          4981           4981
# Clothing                  34487         34487          34487
# Cosmetics                 15097         15097          15097
# Food & Beverage           14776         14776          14776
# Shoes                     10034         10034          10034
# Souvenir                   4999          4999           4999
# Technology                 4996          4996           4996
# Toys                      10087         10087          10087

# %%
branch_sales = df.groupby("shopping_mall").sum()

# %%
category_sales = df.groupby("category").sum()

# %%
branch_sales.sort_values(by = "price", ascending = False)
# Out:
#                                                           invoice_no  \
# shopping_mall
# Mall of Istanbul   I293112I196704I161949I267193I133061I157285I181...
# Kanyon             I138884I337046I326945I336189I252275I768348I147...
# Metrocity          I127801I293455I306368I640508I294687I174250I109...
# Metropol AVM       I173702I993048I473411I138674I218590I195567I297...
# Istinye Park       I121056I195396I209744I202367I664787I148377I204...
# Zorlu Center       I195744I167211I246550I117291I205366I269690I140...
# Cevahir AVM        I179802I992454I412481I823067I655874I221715I870...
# Viaport Outlet     I688768I137794I283443I200392I147334I307534I176...
# Emaar Square Mall  I139207I183746I217053I331891I339732I246562I276...
# Forum Istanbul     I317333I227836I304265I402376I153930I134452I133...
#
#                                                          customer_id  \
# shopping_mall
# Mall of Istanbul   C176086C289625C159164C317818C336576C123427C119...
# Kanyon             C241288C189076C283361C555402C313348C176727C245...
# Metrocity          C266599C159642C240286C225330C300786C204553C232...
# Metropol AVM       C988172C218149C452806C155059C224743C992677C183...
# Istinye Park       C151197C285161C251229C317478C237330C841663C173...
# Zorlu Center       C330667C164092C716788C134449C241642C126436C218...
# Cevahir AVM        C312861C196845C125696C322947C447138C187266C169...
# Viaport Outlet     C362288C133687C189493C307921C306395C434171C876...
# Emaar Square Mall  C191708C220180C192344C501658C276887C227070C136...
# Forum Istanbul     C111565C657758C653385C309926C567813C112750C271...
#
#                                                               gender     age  \
# shopping_mall
# Mall of Istanbul   FemaleFemaleFemaleFemaleMaleMaleMaleFemaleMale...  866333
# Kanyon             FemaleFemaleFemaleFemaleMaleFemaleMaleMaleFema...  862280
# Metrocity          MaleMaleFemaleFemaleMaleFemaleMaleFemaleFemale...  652968
# Metropol AVM       FemaleFemaleMaleMaleFemaleMaleMaleFemaleMaleMa...  439086
# Istinye Park       FemaleMaleMaleFemaleFemaleFemaleFemaleFemaleFe...  424335
# Zorlu Center       FemaleFemaleFemaleMaleFemaleMaleFemaleFemaleFe...  220926
# Cevahir AVM        MaleMaleFemaleMaleFemaleFemaleMaleFemaleFemale...  215474
# Viaport Outlet     MaleFemaleMaleFemaleMaleFemaleFemaleMaleFemale...  212771
# Emaar Square Mall  FemaleMaleMaleMaleMaleFemaleFemaleMaleMaleFema...  209575
# Forum Istanbul     MaleFemaleFemaleMaleMaleFemaleFemaleMaleFemale...  215380
#
#                                                             category  \
# shopping_mall
# Mall of Istanbul   ClothingCosmeticsToysCosmeticsClothingClothing...
# Kanyon             ClothingBooksClothingClothingTechnologyShoesCl...
# Metrocity          ClothingClothingFood & BeverageToysBooksBooksC...
# Metropol AVM       ShoesClothingClothingCosmeticsCosmeticsClothin...
# Istinye Park       CosmeticsToysCosmeticsBooksCosmeticsClothingSo...
# Zorlu Center       Food & BeverageShoesFood & BeverageBooksClothi...
# Cevahir AVM        ClothingToysFood & BeverageClothingShoesFood &...
# Viaport Outlet     ShoesFood & BeverageTechnologyClothingClothing...
# Emaar Square Mall  BooksClothingShoesClothingFood & BeverageCosme...
# Forum Istanbul     ShoesClothingBooksShoesFood & BeverageClothing...
#
#                    quantity        price  \
# shopping_mall
# Mall of Istanbul      60114  13851737.62
# Kanyon                59457  13710755.24
# Metrocity             44894  10249980.07
# Metropol AVM          30530   6937992.99
# Istinye Park          29465   6717077.54
# Zorlu Center          15234   3509649.02
# Cevahir AVM           14949   3433671.84
# Viaport Outlet        14716   3414019.46
# Emaar Square Mall     14501   3390408.31
# Forum Istanbul        14852   3336073.82
#
#                                                       payment_method  \
# shopping_mall
# Mall of Istanbul   Credit CardCredit CardDebit CardCredit CardCre...
# Kanyon             Credit CardCashCredit CardCredit CardCashCredi...
# Metrocity          CashCredit CardCashDebit CardDebit CardCashDeb...
# Metropol AVM       Credit CardCashCashCredit CardDebit CardDebit ...
# Istinye Park       CashDebit CardCredit CardCashCredit CardCashDe...
# Zorlu Center       Credit CardCredit CardCashCredit CardDebit Car...
# Cevahir AVM        CashCashCashCredit CardCashCashCredit CardDebi...
# Viaport Outlet     Credit CardDebit CardCredit CardCredit CardCas...
# Emaar Square Mall  Credit CardCredit CardCashCredit CardCredit Ca...
# Forum Istanbul     Debit CardCredit CardDebit CardCashCashCredit ...
#
#                                                         invoice_date
# shopping_mall
# Mall of Istanbul   13/01/202120/04/20224/7/202212/1/20239/6/20226...
# Kanyon             5/8/202224/10/202122/08/20213/6/202226/10/2021...
# Metrocity          9/11/20214/11/202125/12/202231/07/202216/01/20...
# Metropol AVM       16/05/202126/07/202119/12/202214/02/20229/5/20...
# Istinye Park       13/03/202216/05/202129/04/202124/02/202312/1/2...
# Zorlu Center       5/1/202230/08/202210/9/20219/12/20227/11/20227...
# Cevahir AVM        17/11/20227/3/20231/5/202118/06/202223/08/2022...
# Viaport Outlet     7/11/202112/3/202125/05/202214/09/202112/1/202...
# Emaar Square Mall  28/10/202215/02/202310/10/202221/11/20214/1/20...
# Forum Istanbul     12/12/202124/05/202213/06/202110/9/20229/8/202...

# %%
category_sales.sort_values(by = "price", ascending = False)
# Out:
#                                                         invoice_no  \
# category
# Clothing         I138884I127801I227836I293112I293455I326945I179...
# Shoes            I317333I173702I688768I217053I655874I768348I167...
# Technology       I252275I160777I883721I289643I283443I164665I122...
# Cosmetics        I121056I196704I209744I138674I752693I267193I269...
# Toys             I640508I992454I195396I161949I258195I181109I260...
# Food & Beverage  I306368I195744I412481I339732I246550I137794I263...
# Books            I337046I139207I294687I174250I117291I304265I202...
# Souvenir         I204979I870944I151332I317105I317140I141241I285...
#
#                                                        customer_id  \
# category
# Clothing         C241288C266599C657758C176086C159642C283361C312...
# Shoes            C111565C988172C362288C192344C447138C176727C164...
# Technology       C313348C626042C236859C584700C189493C255058C989...
# Cosmetics        C151197C289625C251229C155059C306662C317818C126...
# Toys             C225330C196845C285161C159164C213742C119549C258...
# Food & Beverage  C240286C330667C125696C276887C716788C133687C112...
# Books            C189076C191708C300786C204553C134449C653385C317...
# Souvenir         C173084C169749C168491C177975C326893C143442C194...
#
#                                                             gender      age  \
# category
# Clothing         FemaleMaleFemaleFemaleMaleFemaleMaleFemaleFema...  1497054
# Shoes            MaleFemaleMaleMaleFemaleFemaleFemaleFemaleFema...   436027
# Technology       MaleFemaleFemaleFemaleMaleFemaleFemaleFemaleFe...   216669
# Cosmetics        FemaleFemaleMaleMaleFemaleFemaleMaleFemaleFema...   657937
# Toys             FemaleMaleMaleFemaleMaleMaleMaleMaleFemaleFema...   437032
# Food & Beverage  FemaleFemaleFemaleMaleFemaleFemaleFemaleFemale...   640605
# Books            FemaleFemaleMaleFemaleMaleFemaleFemaleFemaleFe...   216882
# Souvenir         FemaleMaleMaleFemaleFemaleMaleFemaleFemaleFema...   216922
#
#                  quantity        price  \
# category
# Clothing           103558  31075684.64
# Shoes               30217  18135336.89
# Technology          15021  15772050.00
# Cosmetics           45465   1848606.90
# Toys                30321   1086704.64
# Food & Beverage     44277    231568.71
# Books               14982    226977.30
# Souvenir            14871    174436.83
#
#                                                     payment_method  \
# category
# Clothing         Credit CardCashCredit CardCredit CardCredit Ca...
# Shoes            Debit CardCredit CardCredit CardCashCashCredit...
# Technology       CashCashCredit CardCashCredit CardCashCredit C...
# Cosmetics        CashCredit CardCredit CardCredit CardCashCredi...
# Toys             Debit CardCashDebit CardDebit CardCashCashCash...
# Food & Beverage  CashCredit CardCashCredit CardCashDebit CardCa...
# Books            CashCredit CardDebit CardCashCredit CardDebit ...
# Souvenir         Debit CardCredit CardCashDebit CardCashCredit ...
#
#                                                       invoice_date  \
# category
# Clothing         5/8/20229/11/202124/05/202213/01/20214/11/2021...
# Shoes            12/12/202116/05/20217/11/202110/10/202223/08/2...
# Technology       26/10/202122/02/202219/11/202122/08/202225/05/...
# Cosmetics        13/03/202220/04/202229/04/202114/02/202228/04/...
# Toys             31/07/20227/3/202316/05/20214/7/202226/11/2021...
# Food & Beverage  25/12/20225/1/20221/5/20214/1/202310/9/202112/...
# Books            24/10/202128/10/202216/01/202116/12/20229/12/2...
# Souvenir         14/03/20218/6/202125/03/202129/07/202119/10/20...
#
#                                                      shopping_mall
# category
# Clothing         KanyonMetrocityForum IstanbulMall of IstanbulM...
# Shoes            Forum IstanbulMetropol AVMViaport OutletEmaar ...
# Technology       KanyonMetrocityMall of IstanbulKanyonViaport O...
# Cosmetics        Istinye ParkMall of IstanbulIstinye ParkMetrop...
# Toys             MetrocityCevahir AVMIstinye ParkMall of Istanb...
# Food & Beverage  MetrocityZorlu CenterCevahir AVMEmaar Square M...
# Books            KanyonEmaar Square MallMetrocityMetrocityZorlu...
# Souvenir         Istinye ParkCevahir AVMKanyonKanyonIstinye Par...

# %%
combined_branch_category_sales = df.groupby(["shopping_mall", "category"]).sum()
combined_branch_category_sales
# pie chart for sales by branch
plt.Figure(figsize=(12,21))
plt.pie(branch_sales["price"], labels = branch_sales.index,autopct='%1.1f%%',)
plt.show()

# %%
plt.pie(category_sales["price"], labels = category_sales.index,autopct='%1.1f%%',)
plt.show()

# %%
combined_pivot = df.pivot_table(index="shopping_mall", columns="category", values="price", aggfunc="sum")

# grouped bar chart for sales of different categories at different branches
plt.figure(figsize=(10, 6))
combined_pivot.plot(kind="bar", figsize=(10, 6), edgecolor='black')
plt.title("Sales by Category at Different Branches", fontsize=13, fontweight='bold')
plt.xlabel("Shopping Mall")
plt.ylabel("Total Sales (Price)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
